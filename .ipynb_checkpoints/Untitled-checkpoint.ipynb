# %%
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import numpy as np

# %%
train=pd.read_csv('~/Desktop/kagel_2/train.csv')
test=pd.read_csv('~/Desktop/kagel_2/test.csv')
sample_submission=pd.read_csv('~/Desktop/kagel_2/sample_submission.csv')

# %%
sample_submission # как должен выглядеть ответ
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
train_cols=list(i for i in train.columns)
print(f'train:{train.shape}')
print(f'test:{test.shape}')
# Out:
# train:(1460, 81)
# test:(1459, 80)

# %%
for i in train_cols:
    print(train[i].dtype , i)
# Out:
# int64 Id
# int64 MSSubClass
# object MSZoning
# float64 LotFrontage
# int64 LotArea
# object Street
# object Alley
# object LotShape
# object LandContour
# object Utilities
# object LotConfig
# object LandSlope
# object Neighborhood
# object Condition1
# object Condition2
# object BldgType
# object HouseStyle
# int64 OverallQual
# int64 OverallCond
# int64 YearBuilt
# int64 YearRemodAdd
# object RoofStyle
# object RoofMatl
# object Exterior1st
# object Exterior2nd
# object MasVnrType
# float64 MasVnrArea
# object ExterQual
# object ExterCond
# object Foundation
# object BsmtQual
# object BsmtCond
# object BsmtExposure
# object BsmtFinType1
# int64 BsmtFinSF1
# object BsmtFinType2
# int64 BsmtFinSF2
# int64 BsmtUnfSF
# int64 TotalBsmtSF
# object Heating
# object HeatingQC
# object CentralAir
# object Electrical
# int64 1stFlrSF
# int64 2ndFlrSF
# int64 LowQualFinSF
# int64 GrLivArea
# int64 BsmtFullBath
# int64 BsmtHalfBath
# int64 FullBath
# int64 HalfBath
# int64 BedroomAbvGr
# int64 KitchenAbvGr
# object KitchenQual
# int64 TotRmsAbvGrd
# object Functional
# int64 Fireplaces
# object FireplaceQu
# object GarageType
# float64 GarageYrBlt
# object GarageFinish
# int64 GarageCars
# int64 GarageArea
# object GarageQual
# object GarageCond
# object PavedDrive
# int64 WoodDeckSF
# int64 OpenPorchSF
# int64 EnclosedPorch
# int64 3SsnPorch
# int64 ScreenPorch
# int64 PoolArea
# object PoolQC
# object Fence
# object MiscFeature
# int64 MiscVal
# int64 MoSold
# int64 YrSold
# object SaleType
# object SaleCondition
# int64 SalePrice

# %%
# na = train.isna().sum()/len(train)
# na[na>.30]

# %%
obj = list(train.select_dtypes(include='object').columns)

# %%
intt = list(train.select_dtypes(include='int').columns)

# %%
for i in intt:
    train[i] = train[i].fillna(0)
    train[i] = train[i].astype(float)

# %%
for i in obj:
    train[i] = train[i].fillna('nan')
    train[i] = train[i].astype(str)

# %%
for i in train.columns:
    print(train[i].dtype)
# Out:
# float64
# float64
# object
# float64
# float64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# float64
# float64
# float64
# float64
# object
# object
# object
# object
# object
# float64
# object
# object
# object
# object
# object
# object
# object
# float64
# object
# float64
# float64
# float64
# object
# object
# object
# object
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# float64
# object
# float64
# object
# object
# float64
# object
# float64
# float64
# object
# object
# object
# float64
# float64
# float64
# float64
# float64
# float64
# object
# object
# object
# float64
# float64
# float64
# object
# object
# float64

# %%
train['Alley'].astype(str)
# Out:
# 0       nan
# 1       nan
# 2       nan
# 3       nan
# 4       nan
#        ...
# 1455    nan
# 1456    nan
# 1457    nan
# 1458    nan
# 1459    nan
# Name: Alley, Length: 1460, dtype: object

# %%
train['Alley'].value_counts()
# Out:
# nan     1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64

# %%
train=train[train_cols[1:]]

# %%
train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           60.0       RL         65.0   8450.0   Pave   nan      Reg
# 1           20.0       RL         80.0   9600.0   Pave   nan      Reg
# 2           60.0       RL         68.0  11250.0   Pave   nan      IR1
# 3           70.0       RL         60.0   9550.0   Pave   nan      IR1
# 4           60.0       RL         84.0  14260.0   Pave   nan      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455        60.0       RL         62.0   7917.0   Pave   nan      Reg
# 1456        20.0       RL         85.0  13175.0   Pave   nan      Reg
# 1457        70.0       RL         66.0   9042.0   Pave   nan      Reg
# 1458        20.0       RL         68.0   9717.0   Pave   nan      Reg
# 1459        20.0       RL         75.0   9937.0   Pave   nan      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    Inside  ...      0.0    nan    nan         nan
# 1            Lvl    AllPub       FR2  ...      0.0    nan    nan         nan
# 2            Lvl    AllPub    Inside  ...      0.0    nan    nan         nan
# 3            Lvl    AllPub    Corner  ...      0.0    nan    nan         nan
# 4            Lvl    AllPub       FR2  ...      0.0    nan    nan         nan
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1455         Lvl    AllPub    Inside  ...      0.0    nan    nan         nan
# 1456         Lvl    AllPub    Inside  ...      0.0    nan  MnPrv         nan
# 1457         Lvl    AllPub    Inside  ...      0.0    nan  GdPrv        Shed
# 1458         Lvl    AllPub    Inside  ...      0.0    nan    nan         nan
# 1459         Lvl    AllPub    Inside  ...      0.0    nan    nan         nan
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0        0.0    2.0  2008.0        WD         Normal   208500.0
# 1        0.0    5.0  2007.0        WD         Normal   181500.0
# 2        0.0    9.0  2008.0        WD         Normal   223500.0
# 3        0.0    2.0  2006.0        WD        Abnorml   140000.0
# 4        0.0   12.0  2008.0        WD         Normal   250000.0
# ...      ...    ...     ...       ...            ...        ...
# 1455     0.0    8.0  2007.0        WD         Normal   175000.0
# 1456     0.0    2.0  2010.0        WD         Normal   210000.0
# 1457  2500.0    5.0  2010.0        WD         Normal   266500.0
# 1458     0.0    4.0  2010.0        WD         Normal   142125.0
# 1459     0.0    6.0  2008.0        WD         Normal   147500.0
#
# [1460 rows x 80 columns]

# %%
for i in train.columns:
    print(train[i].dtype)
# Out:
# float64
# object
# float64
# float64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# float64
# float64
# float64
# float64
# object
# object
# object
# object
# object
# float64
# object
# object
# object
# object
# object
# object
# object
# float64
# object
# float64
# float64
# float64
# object
# object
# object
# object
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# float64
# object
# float64
# object
# object
# float64
# object
# float64
# float64
# object
# object
# object
# float64
# float64
# float64
# float64
# float64
# float64
# object
# object
# object
# float64
# float64
# float64
# object
# object
# float64

# %%
X=train[train_cols[1:-1]]

# %%
y=train[train_cols[-1]]

# %%
y
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Name: SalePrice, Length: 1460, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2)

# %%
X_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 540         20.0       RL         85.0  14601.0   Pave   nan      Reg
# 93         190.0  C (all)         60.0   7200.0   Pave   nan      Reg
# 1032        60.0       RL          NaN  14541.0   Pave   nan      IR1
# 1207        20.0       RL         70.0   9135.0   Pave   nan      Reg
# 343        120.0       RL         63.0   8849.0   Pave   nan      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 182         20.0       RL         60.0   9060.0   Pave   nan      Reg
# 1137        50.0       RL         54.0   6342.0   Pave   nan      Reg
# 94          60.0       RL         69.0   9337.0   Pave   nan      IR1
# 704         20.0       RL         70.0   8400.0   Pave   nan      Reg
# 128         60.0       RL         69.0   7590.0   Pave   nan      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 540          Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 93           Lvl    AllPub    Corner  ...        99.0      0.0    nan    nan
# 1032         Lvl    AllPub    Corner  ...         0.0      0.0    nan    nan
# 1207         Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 343          Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 182          Lvl    AllPub    Inside  ...         0.0      0.0    nan  MnPrv
# 1137         Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 94           Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 704          Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 128          Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 540          nan     0.0     3.0  2009.0        WD         Normal
# 93           nan     0.0    11.0  2007.0        WD         Normal
# 1032         nan     0.0    11.0  2006.0        WD        Abnorml
# 1207         nan     0.0     5.0  2006.0        WD         Normal
# 343          nan     0.0     7.0  2008.0        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 182          nan     0.0     6.0  2007.0        WD         Normal
# 1137         nan     0.0     5.0  2010.0        WD         Normal
# 94           nan     0.0     5.0  2007.0        WD         Normal
# 704          nan     0.0     5.0  2010.0        WD         Normal
# 128          nan     0.0     7.0  2006.0        WD         Normal
#
# [1168 rows x 79 columns]

# %%
X=X_train
y=y_train

# %%
X
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 540         20.0       RL         85.0  14601.0   Pave   nan      Reg
# 93         190.0  C (all)         60.0   7200.0   Pave   nan      Reg
# 1032        60.0       RL          NaN  14541.0   Pave   nan      IR1
# 1207        20.0       RL         70.0   9135.0   Pave   nan      Reg
# 343        120.0       RL         63.0   8849.0   Pave   nan      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 182         20.0       RL         60.0   9060.0   Pave   nan      Reg
# 1137        50.0       RL         54.0   6342.0   Pave   nan      Reg
# 94          60.0       RL         69.0   9337.0   Pave   nan      IR1
# 704         20.0       RL         70.0   8400.0   Pave   nan      Reg
# 128         60.0       RL         69.0   7590.0   Pave   nan      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 540          Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 93           Lvl    AllPub    Corner  ...        99.0      0.0    nan    nan
# 1032         Lvl    AllPub    Corner  ...         0.0      0.0    nan    nan
# 1207         Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 343          Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 182          Lvl    AllPub    Inside  ...         0.0      0.0    nan  MnPrv
# 1137         Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 94           Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 704          Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
# 128          Lvl    AllPub    Inside  ...         0.0      0.0    nan    nan
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 540          nan     0.0     3.0  2009.0        WD         Normal
# 93           nan     0.0    11.0  2007.0        WD         Normal
# 1032         nan     0.0    11.0  2006.0        WD        Abnorml
# 1207         nan     0.0     5.0  2006.0        WD         Normal
# 343          nan     0.0     7.0  2008.0        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 182          nan     0.0     6.0  2007.0        WD         Normal
# 1137         nan     0.0     5.0  2010.0        WD         Normal
# 94           nan     0.0     5.0  2007.0        WD         Normal
# 704          nan     0.0     5.0  2010.0        WD         Normal
# 128          nan     0.0     7.0  2006.0        WD         Normal
#
# [1168 rows x 79 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

for i in obj:
    X[i]= label_encoder.fit_transform(X[i])

# %%
model = XGBRegressor()

# %%
model
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None)

# %%
model.fit(X_train,y_train)
# model.score(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
model.score(X_train,y_train)
# Out:
# /usr/lib/python3.9/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# 0.9998336587183738

# %%
X
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 540         20.0         3         85.0  14601.0       1      2         3
# 93         190.0         0         60.0   7200.0       1      2         3
# 1032        60.0         3          NaN  14541.0       1      2         0
# 1207        20.0         3         70.0   9135.0       1      2         3
# 343        120.0         3         63.0   8849.0       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 182         20.0         3         60.0   9060.0       1      2         3
# 1137        50.0         3         54.0   6342.0       1      2         3
# 94          60.0         3         69.0   9337.0       1      2         0
# 704         20.0         3         70.0   8400.0       1      2         3
# 128         60.0         3         69.0   7590.0       1      2         3
#
#       LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# 540             3          0          4  ...          0.0       0.0       3
# 93              3          0          0  ...         99.0       0.0       3
# 1032            3          0          0  ...          0.0       0.0       3
# 1207            3          0          4  ...          0.0       0.0       3
# 343             3          0          4  ...          0.0       0.0       3
# ...           ...        ...        ...  ...          ...       ...     ...
# 182             3          0          4  ...          0.0       0.0       3
# 1137            3          0          4  ...          0.0       0.0       3
# 94              3          0          4  ...          0.0       0.0       3
# 704             3          0          4  ...          0.0       0.0       3
# 128             3          0          4  ...          0.0       0.0       3
#
#       Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 540       4            4      0.0     3.0  2009.0         8              4
# 93        4            4      0.0    11.0  2007.0         8              4
# 1032      4            4      0.0    11.0  2006.0         8              0
# 1207      4            4      0.0     5.0  2006.0         8              4
# 343       4            4      0.0     7.0  2008.0         8              4
# ...     ...          ...      ...     ...     ...       ...            ...
# 182       2            4      0.0     6.0  2007.0         8              4
# 1137      4            4      0.0     5.0  2010.0         8              4
# 94        4            4      0.0     5.0  2007.0         8              4
# 704       4            4      0.0     5.0  2010.0         8              4
# 128       4            4      0.0     7.0  2006.0         8              4
#
# [1168 rows x 79 columns]

# %%
for i in obj:
    X_test[i]= label_encoder.fit_transform(X_test[i])

# %%
model.score(X_test,y_test)
# Out:
# /usr/lib/python3.9/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# 0.7406012153506774

# %%
y_pred = model.predict(X_test)
# Out:
# /usr/lib/python3.9/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
from sklearn.metrics import mean_squared_log_error
np.sqrt(mean_squared_log_error(y_test, y_pred))


model.fit(X,y,verbose=False)
model.score(X,y)



y_pred = model.predict(test)

sub = pd.DataFrame({'id':range(1461,1461+len(test)),'SalePrice':y_pred})
sub.to_csv('submission.csv',index=False)
# Out:
# /usr/lib/python3.9/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5332/1292467654.py in <module>
#       8
#       9
# ---> 10 y_pred = model.predict(test)
#      11
#      12 sub = pd.DataFrame({'id':range(1461,1461+len(test)),'SalePrice':y_pred})
#
# /usr/lib/python3.9/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     818         if self._can_use_inplace_predict():
#     819             try:
# --> 820                 predts = self.get_booster().inplace_predict(
#     821                     data=X,
#     822                     iteration_range=iteration_range,
#
# /usr/lib/python3.9/site-packages/xgboost/core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    1836         if validate_features:
#    1837             if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 1838                 raise ValueError(
#    1839                     f"Feature shape mismatch, expected: {self.num_features()}, "
#    1840                     f"got {data.shape[0]}"
#
# ValueError: Feature shape mismatch, expected: 79, got 1459

# %%
for i in obj:
    test[i]= label_encoder.fit_transform(test[i])

# %%
test = test.drop(columns=['Id'])
